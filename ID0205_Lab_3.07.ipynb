# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/ComputationalGeometry/blob/main/ID0205_Lab_3.07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ID0205 - Geometría Computacional
#
# ### Primavera 2023
#
# ### ID0205_Lab-3.07
#
# **Profesor Enrique Naredo García**
#
# <font size = 2>
# ©️ Todos los derechos reservados. All rights reserved.
#
# *Nota: El presente documento es una herramienta diseñada única y exclusivamente para los estudiantes de la asignatura arriba mencionada. Queda prohibido compartir este documento entre otros estudiantes, aún siendo de la misma clase, grupo o de la Universidad sin consentimiento del autor. Queda prohibida la reproducción total o parcial de este documento por cualquier medio o procedimiento, ya sea electrónico o mecánico, el tratamiento informático, el alquiler o cualquier otra forma de cesión sin la autorización previa y por escrito del titular del copyright.*
# </font>

# %% [markdown]
# ## Generación de gráficos de conglomerados
#
# Este ejemplo muestra cómo encontrar las comunidades en un gráfico, luego contraer cada comunidad en un solo nodo usando la calse:`igraph.clustering.VertexClustering`.
#
# * En este ejemplo utilizamos la *Red de Los Miserables de Donald Knuth*, que muestra las apariencias de los personajes de la novela *Los Miserables*, aquí esta el [enlace](http://www-personal.umich.edu/~mejn/netdata/).

# %%
# instal igraph
# !pip install igraph
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting igraph
#   Downloading igraph-0.10.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 32.8 MB/s eta 0:00:00
# Collecting texttable>=1.6.2
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
# Successfully installed igraph-0.10.4 texttable-1.6.7

# %%
# importa librerías
import igraph as ig
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Comenzamos descargando [aquí](http://www-personal.umich.edu/~mejn/netdata/) el archivo 'lesmis.gml' que contiene esta red.
#
# * Puedes descargar este archivo en tu disco local.
# * Se tiene que guardar el archivo en tu Google drive.
# * Puedes abrir el folder que se muestra a la izquierda de este notebook.
# * Ahí encontrarás un folder nombrado: 'sample_data'
# * Podrías arrastrar y soltar el archivo 'lesmis.gml' en el folder 'sample_data'.
# * Ya que lo tengas en este folder, usa el cursor (flecha) y aparecerá del lado derecho 3 puntos, da clic en 'Copy path' (o en español 'Copia ruta').
# * finalmente copia esa ruta como se muestra en la siguiente celda.

# %%
# aquí copia la ruta para encontrar el archivo en tu drive
g = ig.load("/content/lesmis.gml")

# %% [markdown]
# Con este archivo podemos generar comunidades usando `igraph.Graph.community_edge_ betweenness` para separar los vértices en grupos.

# %%
# generar comunidades
communities = g.community_edge_betweenness()

# %% [markdown]
# Para parcelas, es conveniente convertir las comunidades en un VertexClustering:

# %%
# convertir las comunidades en un VertexClustering
communities = communities.as_clustering()

# %% [markdown]
# También podemos imprimir fácilmente quién pertenece a cada comunidad.

# %%
# imprimir quién pertenece a cada comunidad
for i, community in enumerate(communities):
    print(f"Community {i}:")
    for v in community:
        print(f"\t{g.vs[v]['label']}")
# Out:
# Community 0:
# 	Myriel
# 	Napoleon
# 	MlleBaptistine
# 	MmeMagloire
# 	CountessDeLo
# 	Geborand
# 	Champtercier
# 	Cravatte
# 	Count
# 	OldMan
# Community 1:
# 	Labarre
# 	Valjean
# 	MmeDeR
# 	Isabeau
# 	Gervais
# 	Bamatabois
# 	Simplice
# 	Scaufflaire
# 	Woman1
# 	Judge
# 	Champmathieu
# 	Brevet
# 	Chenildieu
# 	Cochepaille
# Community 2:
# 	Marguerite
# 	Tholomyes
# 	Listolier
# 	Fameuil
# 	Blacheville
# 	Favourite
# 	Dahlia
# 	Zephine
# 	Fantine
# 	Perpetue
# Community 3:
# 	MmeThenardier
# 	Thenardier
# 	Javert
# 	Pontmercy
# 	Eponine
# 	Anzelma
# 	Gueulemer
# 	Babet
# 	Claquesous
# 	Montparnasse
# 	Brujon
# Community 4:
# 	Cosette
# 	Woman2
# 	Gillenormand
# 	Magnon
# 	MlleGillenormand
# 	MmePontmercy
# 	MlleVaubois
# 	LtGillenormand
# 	BaronessT
# 	Toussaint
# Community 5:
# 	Fauchelevent
# 	MotherInnocent
# 	Gribier
# Community 6:
# 	Boulatruelle
# Community 7:
# 	Jondrette
# 	MmeBurgon
# Community 8:
# 	Gavroche
# 	Marius
# 	Mabeuf
# 	Enjolras
# 	Combeferre
# 	Prouvaire
# 	Feuilly
# 	Courfeyrac
# 	Bahorel
# 	Bossuet
# 	Joly
# 	Grantaire
# 	MmeHucheloup
# Community 9:
# 	MotherPlutarch
# Community 10:
# 	Child1
# 	Child2

# %% [markdown]
# Finalmente, podemos proceder a trazar el gráfico.
#
# * Para que cada comunidad se destaque, establecemos los "colores de la comunidad" usando una paleta de 'igraph'.

# %%
# destacar comunidades con colores
num_communities = len(communities)
palette1 = ig.RainbowPalette(n=num_communities)
for i, community in enumerate(communities):
    g.vs[community]["color"] = i
    community_edges = g.es.select(_within=community)
    community_edges["color"] = i

# %% [markdown]
# Podemos usar un truco (no tan bueno) para mover las etiquetas debajo de los vértices.

# %%
# mover las etiquetas debajo de los vértices
g.vs["label"] = ["\n\n" + label for label in g.vs["label"]]

# %% [markdown]
# Finalmente, podemos graficar las comunidades:

# %%
# Graficar las comunidades
fig1, ax1 = plt.subplots()
ig.plot(
    communities,
    target=ax1,
    mark_groups=True,
    palette=palette1,
    vertex_size=0.1,
    edge_width=0.5,
)
fig1.set_size_inches(20, 20)

# %% [markdown]
# Ahora intentemos reducir la información, usando un solo vértice para representar cada comunidad.
#
# * Comenzamos definiendo los atributos $x$, $y$, y el tamaño para cada nodo en el gráfico original:

# %%
# definir atributos x, y, y el tamaño de cada nodo
layout = g.layout_kamada_kawai()
g.vs["x"], g.vs["y"] = list(zip(*layout))
g.vs["size"] = 1
g.es["size"] = 1

# %% [markdown]
# Ahora, podemos generar el gráfico de clúster que comprime cada comunidad en un solo vértice.

# %%
# generar el gráfico de clúster
cluster_graph = communities.cluster_graph(
    combine_vertices={
        "x": "mean",
        "y": "mean",
        "color": "first",
        "size": "sum",
    },
    combine_edges={
        "size": "sum",
    },
)

# %% [markdown]
# * Tomamos la media de los valores de $x$ e $y$ para que los nodos en el gráfico de conglomerados se coloquen en el centroide del conglomerado original.
#
#
# * También podemos definir funciones propias de contracción personalizadas, que tomen una lista y devuelvan un solo elemento que representa el valor del atributo combinado.

# %% [markdown]
# Finalmente, podemos asignar colores a los conglomerados y trazar el gráfico de conglomerados, incluyendo una leyenda para aclarar las cosas.

# %%
palette2 = ig.GradientPalette("gainsboro", "black")
g.es["color"] = [palette2.get(int(i)) for i in ig.rescale(cluster_graph.es["size"], (0, 255), clamp=True)]

# %%
# Crea la figura
fig2, ax2 = plt.subplots()
ig.plot(
    cluster_graph,
    target=ax2,
    palette=palette1,
    # set a minimum size on vertex_size, otherwise vertices are too small
    vertex_size=[max(0.2, size / 20) for size in cluster_graph.vs["size"]],
    edge_color=g.es["color"],
    edge_width=0.8,
)
# Out:
# <Axes: >

# %%
# Agrega una leyenda
legend_handles = []

for i in range(num_communities):
    handle = ax2.scatter(
        [], [],
        s=100,
        facecolor=palette1.get(i),
        edgecolor="k",
        label=i,
    )
    legend_handles.append(handle)

ax2.legend(
    handles=legend_handles,
    title='Community:',
    bbox_to_anchor=(0, 1.0),
    bbox_transform=ax2.transAxes,
)

fig2.set_size_inches(10, 10)

# %% [markdown]
# ###Ejercicio
#
# Utiliza uno de los archivos que vienen en este [link](http://www-personal.umich.edu/~mejn/netdata/) para replicar el ejemplo anterior.
#
# * Utiliza diferentes colores.
# * Utiliza un titulo descriptivo del problema que abordas.
# * Cambia el nombre de la mayor parte de código que puedas.
# * Renombra variables en español.
# * Recuerda agregar una introducción al principio describiendo el archivo escogido y el problema de cual se trata.
# * Agreguen al final una sección de conclusiones
# y referencias.

# %% [markdown]
# #**Introducción:**
# La información usada se refiere a una red neuronal que representa las conexiones neuronales en el gusano nematodo, C. elegans. La red está dirigida y ponderada, lo que significa que las conexiones entre las neuronas tienen una dirección y una fuerza.
#
# Los datos utilizados para crear esta red neuronal fueron recopilados por D. Watts y S. Strogatz, y se obtuvieron originalmente de un estudio experimental de C. elegans realizado por J. G. White, E. Southgate, J. N. Thompson y S. Brenner. Los datos están disponibles en la web y fueron publicados en un artículo de Nature por Watts y Strogatz en 1998.
#
# Esta red neuronal es significativa porque es el primer ejemplo de una red neuronal completa para un organismo multicelular. C. elegans tiene un sistema nervioso relativamente simple con solo 302 neuronas, lo que lo convierte en un modelo ideal para estudiar redes neuronales. La red neuronal de C. elegans se ha estudiado ampliamente y ha brindado información importante sobre cómo funcionan las redes neuronales y cómo se pueden usar para controlar el comportamiento.

# %%
# Aquí copia la ruta para encontrar el archivo en tu drive
red_neuronal = ig.load("/content/celegansneural.gml") 

# Generar comunidades
comunidades = red_neuronal.community_edge_betweenness()

# Convertir las comunidades en un VertexClustering
comunidades = comunidades.as_clustering()

# Imprimir quién pertenece a cada comunidad
for i, comunidad in enumerate(comunidades):
    print(f"Comunidad {i}:")
    for v in comunidad:
        print(f"\t{red_neuronal.vs[v]['label']}")

# Destacar comunidades con colores
num_comunidades = len(comunidades)
paleta = ig.RainbowPalette(n=num_comunidades)
for i, comunidad in enumerate(comunidades):
    red_neuronal.vs[comunidad]["color"] = i
    edges_comunidad = red_neuronal.es.select(_within=comunidad)
    edges_comunidad["color"] = i

# Mover las etiquetas debajo de los vértices
red_neuronal.vs["label"] = ["\n\n" + label for label in red_neuronal.vs["label"]]

# Graficar las comunidades
fig, ax = plt.subplots()
ig.plot(
    comunidades,
    target=ax,
    mark_groups=True,
    palette=paleta,
    vertex_size=0.1,
    edge_width=0.5,
)
fig.set_size_inches(20, 20)
plt.title("Red Neuronal")
# Out:
# Comunidad 0:
# 	1
# Comunidad 1:
# 	51
# 	125
# 	126
# 	140
# 	107
# 	73
# 	74
# 	135
# 	104
# 	202
# 	185
# Comunidad 2:
# 	72
# Comunidad 3:
# 	77
# 	94
# 	52
# 	123
# 	184
# Comunidad 4:
# 	78
# Comunidad 5:
# 	2
# Comunidad 6:
# 	90
# Comunidad 7:
# 	92
# Comunidad 8:
# 	158
# Comunidad 9:
# 	159
# Comunidad 10:
# 	113
# Comunidad 11:
# 	69
# Comunidad 12:
# 	71
# Comunidad 13:
# 	89
# Comunidad 14:
# 	91
# Comunidad 15:
# 	3
# Comunidad 16:
# 	47
# Comunidad 17:
# 	9
# Comunidad 18:
# 	17
# Comunidad 19:
# 	21
# Comunidad 20:
# 	93
# Comunidad 21:
# 	23
# 	141
# Comunidad 22:
# 	121
# 	129
# 	171
# Comunidad 23:
# 	131
# Comunidad 24:
# 	31
# Comunidad 25:
# 	4
# Comunidad 26:
# 	60
# Comunidad 27:
# 	10
# Comunidad 28:
# 	16
# Comunidad 29:
# 	18
# Comunidad 30:
# 	22
# Comunidad 31:
# 	24
# Comunidad 32:
# 	97
# Comunidad 33:
# 	122
# Comunidad 34:
# 	132
# Comunidad 35:
# 	32
# Comunidad 36:
# 	303
# 	39
# 	111
# Comunidad 37:
# 	5
# Comunidad 38:
# 	7
# Comunidad 39:
# 	222
# Comunidad 40:
# 	101
# Comunidad 41:
# 	305
# 	189
# 	80
# 	178
# 	220
# 	221
# 	146
# 	225
# 	226
# 	227
# 	187
# 	188
# 	249
# 	250
# 	251
# 	197
# 	117
# 	276
# 	306
# 	177
# 	199
# 	169
# 	148
# 	168
# 	147
# 	153
# 	196
# 	149
# 	275
# 	205
# 	206
# 	151
# 	277
# 	152
# 	245
# 	278
# 	167
# 	269
# 	175
# 	176
# 	272
# 	270
# 	258
# 	181
# 	182
# 	274
# 	190
# 	191
# 	194
# 	244
# 	207
# 	208
# 	209
# 	210
# 	264
# 	282
# 	279
# 	231
# 	280
# 	232
# 	281
# 	233
# 	246
# 	247
# 	248
# 	243
# 	257
# 	259
# 	267
# 	268
# 	271
# 	273
# 	291
# 	292
# 	293
# 	294
# 	295
# 	296
# 	297
# 	298
# 	299
# 	300
# 	301
# 	302
# Comunidad 42:
# 	6
# Comunidad 43:
# 	102
# Comunidad 44:
# 	99
# Comunidad 45:
# 	100
# Comunidad 46:
# 	27
# Comunidad 47:
# 	8
# Comunidad 48:
# 	26
# Comunidad 49:
# 	44
# Comunidad 50:
# 	37
# Comunidad 51:
# 	11
# Comunidad 52:
# 	19
# Comunidad 53:
# 	29
# Comunidad 54:
# 	12
# Comunidad 55:
# 	41
# Comunidad 56:
# 	118
# Comunidad 57:
# 	25
# Comunidad 58:
# 	30
# Comunidad 59:
# 	13
# Comunidad 60:
# 	143
# Comunidad 61:
# 	28
# Comunidad 62:
# 	43
# Comunidad 63:
# 	14
# Comunidad 64:
# 	144
# Comunidad 65:
# 	20
# Comunidad 66:
# 	34
# Comunidad 67:
# 	15
# Comunidad 68:
# 	40
# Comunidad 69:
# 	128
# Comunidad 70:
# 	139
# Comunidad 71:
# 	108
# Comunidad 72:
# 	35
# Comunidad 73:
# 	133
# Comunidad 74:
# 	134
# Comunidad 75:
# 	105
# Comunidad 76:
# 	106
# Comunidad 77:
# 	36
# Comunidad 78:
# 	33
# Comunidad 79:
# 	136
# Comunidad 80:
# 	161
# Comunidad 81:
# 	120
# Comunidad 82:
# 	38
# Comunidad 83:
# 	160
# Comunidad 84:
# 	130
# Comunidad 85:
# 	174
# Comunidad 86:
# 	42
# Comunidad 87:
# 	82
# Comunidad 88:
# 	70
# Comunidad 89:
# 	45
# Comunidad 90:
# 	55
# Comunidad 91:
# 	119
# Comunidad 92:
# 	137
# Comunidad 93:
# 	46
# Comunidad 94:
# 	142
# Comunidad 95:
# 	114
# Comunidad 96:
# 	56
# Comunidad 97:
# 	62
# Comunidad 98:
# 	86
# Comunidad 99:
# 	193
# Comunidad 100:
# 	138
# Comunidad 101:
# 	109
# Comunidad 102:
# 	58
# Comunidad 103:
# 	61
# Comunidad 104:
# 	75
# Comunidad 105:
# 	76
# Comunidad 106:
# 	81
# Comunidad 107:
# 	85
# Comunidad 108:
# 	48
# Comunidad 109:
# 	110
# Comunidad 110:
# 	88
# Comunidad 111:
# 	216
# Comunidad 112:
# 	49
# Comunidad 113:
# 	54
# Comunidad 114:
# 	50
# Comunidad 115:
# 	154
# Comunidad 116:
# 	96
# Comunidad 117:
# 	127
# Comunidad 118:
# 	95
# Comunidad 119:
# 	166
# Comunidad 120:
# 	53
# Comunidad 121:
# 	57
# Comunidad 122:
# 	63
# Comunidad 123:
# 	198
# Comunidad 124:
# 	87
# Comunidad 125:
# 	84
# Comunidad 126:
# 	59
# Comunidad 127:
# 	67
# Comunidad 128:
# 	64
# Comunidad 129:
# 	65
# Comunidad 130:
# 	66
# Comunidad 131:
# 	68
# Comunidad 132:
# 	112
# Comunidad 133:
# 	186
# Comunidad 134:
# 	228
# Comunidad 135:
# 	229
# Comunidad 136:
# 	230
# Comunidad 137:
# 	150
# 	172
# Comunidad 138:
# 	234
# Comunidad 139:
# 	235
# Comunidad 140:
# 	236
# Comunidad 141:
# 	237
# Comunidad 142:
# 	238
# Comunidad 143:
# 	239
# Comunidad 144:
# 	240
# Comunidad 145:
# 	242
# Comunidad 146:
# 	203
# Comunidad 147:
# 	179
# Comunidad 148:
# 	217
# Comunidad 149:
# 	162
# Comunidad 150:
# 	164
# Comunidad 151:
# 	195
# Comunidad 152:
# 	252
# Comunidad 153:
# 	253
# Comunidad 154:
# 	254
# Comunidad 155:
# 	255
# Comunidad 156:
# 	204
# Comunidad 157:
# 	180
# Comunidad 158:
# 	163
# Comunidad 159:
# 	256
# Comunidad 160:
# 	241
# Comunidad 161:
# 	200
# Comunidad 162:
# 	215
# Comunidad 163:
# 	165
# Comunidad 164:
# 	79
# Comunidad 165:
# 	145
# Comunidad 166:
# 	192
# Comunidad 167:
# 	219
# Comunidad 168:
# 	157
# Comunidad 169:
# 	218
# Comunidad 170:
# 	83
# Comunidad 171:
# 	98
# Comunidad 172:
# 	124
# Comunidad 173:
# 	103
# Comunidad 174:
# 	115
# Comunidad 175:
# 	156
# Comunidad 176:
# 	170
# Comunidad 177:
# 	183
# Comunidad 178:
# 	116
# Comunidad 179:
# 	224
# Comunidad 180:
# 	214
# Comunidad 181:
# 	213
# Comunidad 182:
# 	155
# Comunidad 183:
# 	173
# Comunidad 184:
# 	201
# Comunidad 185:
# 	260
# Comunidad 186:
# 	223
# Comunidad 187:
# 	211
# Comunidad 188:
# 	212
# Comunidad 189:
# 	261
# Comunidad 190:
# 	262
# Comunidad 191:
# 	263
# Comunidad 192:
# 	265
# Comunidad 193:
# 	266
# Text(0.5, 1.0, 'Red Neuronal')

# %% [markdown]
# #**Conclusiones:**
# Este código muestra cómo se puede utilizar la biblioteca de Python "igraph" para analizar redes complejas y detectar comunidades dentro de ellas. En particular, este código carga una red neuronal de C. elegans desde un archivo GML, aplica un algoritmo de detección de comunidades basado en la "edge betweenness" y utiliza una paleta de colores para visualizar las diferentes comunidades encontradas en la red.
#
# La capacidad de detectar comunidades en redes es útil en muchas aplicaciones, como en el análisis de redes sociales, biológicas, financieras, entre otras. La visualización de las comunidades en la red puede proporcionar información valiosa para comprender la estructura y organización de la red, y cómo los nodos están interconectados entre sí.
# #**Referencias:**
# - Network data. (s. f.). http://www-personal.umich.edu/%7Emejn/netdata/
