# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiagoldheart/ComputationalGeometry/blob/main/ID0205_Lab_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ID0205 - Geometría Computacional
#
# ### Primavera 2023
#
# Ejercicio #: ID0205_Lab2_05
#
# Sección: 01
#
# ID: 210300529
#
# Nombre completo: Sofia Ruvalcaba de la Noval
#
# Profesor: Enrique Naredo García

# %% [markdown]
# ##Intoducción
# En el presente notebook podremos aprender sobre los usos de las librerias 'matplotlib.pyplot' y 'numpy' en la graficación de puntos en un plano cartesiano, trazo de rectas, cambio de colores de las lineas o tamaño de los puntos, visualizar los catetos e hipotenusa, entre otros.

# %% [markdown]
# ## Usando matplotlib

# %%
# Librerias 
import matplotlib.pyplot as plt

# %%
# Definine 3 puntos
point1 = [1,1]
point2 = [2,2.5]
point3 = [3, 1]

# %%
# Abcisas del triángulo
triangleX = [point1[0],point2[0],point3[0]]

# Ordenadas del triángulo
triangleY = [point1[1],point2[1],point3[1]]

# %%
# Grafica puntos
plt.figure()
plt.scatter(triangleX, triangleY, s = 100, color = 'red')

# %%
# Crea una figura
plt.figure()

# se requiere repetir el primer punto (abicisa)
triangleX2 = triangleX
triangleX2.append(point1[0])

# se requiere repetir el primer punto (ordenada)
triangleY2 = triangleY
triangleY2.append(point1[1])

# Grafica triángulo
plt.plot(triangleX2, triangleY2, marker = 'o')
plt.show()

# %% [markdown]
# **Ejercicio**
#
# Siguiendo el ejemplo anterior, dibuja un triángulo usando los siguientes datos:
#
# * $[8, 7.5], [7, 9], [9, 9]$.
#
# * Dibuja las líneas en color rojo.
#
# * Los puntos en color verde.

# %%
# Librerias 
import matplotlib.pyplot as plt
# Definine 3 puntos
point1 = [8,7.5]
point2 = [7,9]
point3 = [9,9]
# Abcisas del triángulo
triangleX = [point1[0],point2[0],point3[0]]
# Ordenadas del triángulo
triangleY = [point1[1],point2[1],point3[1]]
# Grafica puntos
#plt.figure()
plt.scatter(triangleX, triangleY, s = 100, color= 'green') #puntos
# Crea una figura
#plt.figure()

# se requiere repetir el primer punto (abicisa)
triangleX2 = triangleX
triangleX2.append(point1[0])

# se requiere repetir el primer punto (ordenada)
triangleY2 = triangleY
triangleY2.append(point1[1])

# Grafica triángulo
plt.plot(triangleX2, triangleY2, color='red') #lineas
plt.show()

# %%
# Librerias 
import numpy as np
import matplotlib.pyplot as plt
# Definine 3 puntos
point1 = [8,7.5]
point2 = [7,9]
point3 = [9,9]
# Abcisas del triángulo
triangleX = [point1[0],point2[0],point3[0]]
# Ordenadas del triángulo
triangleY = [point1[1],point2[1],point3[1]]
# Grafica puntos
#plt.figure()
plt.scatter(triangleX, triangleY, s = [100,200,300], color= ['green', 'red', 'blue']) #puntos
# Crea una figura
#plt.figure()

# se requiere repetir el primer punto (abicisa)
triangleX2 = triangleX
triangleX2.append(point1[0])

# se requiere repetir el primer punto (ordenada)
triangleY2 = triangleY
triangleY2.append(point1[1])

# Grafica triángulo
plt.plot(triangleX2, triangleY2, color = 'c') #lineas
plt.show()

# %% [markdown]
# ## Usando Numpy

# %%
# Librerias
import numpy as np 
import scipy as sp
import pandas as pd

# %%
# Triángulo rectángulo
x=np.array([0,4,4,0])
y=np.array([0,0,3,0])

# %%
# Figura
fig1=plt.figure(1)

# Gráfica Triángulo 
color1 = [0/255,176/255,80/255]
plt.plot(x,y,color=color1,linewidth=4)

# Limites de ejes
plt.xlim([-1,7])
plt.ylim([-1,7])

# Cuadricula
color2 = [166/255,166/255,166/255]
plt.grid(axis='both',which='major',color=color2, linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=color2, linestyle=':', linewidth=1)

# %%
#Figura
fig1=plt.figure(1)

# Grafica Triángulo 
color1 = [0/255,176/255,80/255]
plt.plot(x,y,color=color1,linewidth=4)

# Limites de ejes
plt.xlim([-1,7])
plt.ylim([-1,7])

# Cuadricula
color2 = [166/255,166/255,166/255]
plt.grid(axis='both',which='major',color=color2, linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=color2, linestyle=':', linewidth=1)

# Agrega texto
plt.text(0.5,0.25,'θ')
plt.text(3.5,0.25,'90°')
plt.text(3.5,2.25,'γ')
plt.text(1.5,-0.5,'Adyacente (A)')
plt.text(4.5,1.5,'Opuesto (O)')
plt.text(0,2,'Hipotenusa (H)')
# Out:
# Text(0, 2, 'Hipotenusa (H)')

# %% [markdown]
# **Ejercicio**
#
# Utiliza el ejemplo anterior y los siguientes puntos para dibujar un triángulo rojo:
#
# * punto1 = [1,1]
# * punto2 = [2,2.5]
# * punto3 = [3, 1]

# %%
# Librerias
import numpy as np 
import scipy as sp
import pandas as pd

# Triángulo rectángulo
x=np.array([1,2,3,1])
y=np.array([1,2.5,1,1])

# Figura
fig1=plt.figure(1)

# Gráfica Triángulo 
color1 = [192/255,0/255,0/255]
plt.plot(x,y,color=color1,linewidth=3)

# Limites de ejes
plt.xlim([-1,7])
plt.ylim([-1,7])

# Cuadricula
color2 = [166/255,166/255,166/255]
plt.grid(axis='both',which='major',color=color2, linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=color2, linestyle=':', linewidth=1)

# %% [markdown]
# **Ejercicio**
#
# Utiliza el siguiente arreglo y los siguientes textos para construir un triángulo rectángulo:
#
# * triangX = $[0,4/5,4/5,0]$
#
# * triangY = $[0,0,3/5,0]$
#
# * Alfa (\alpha)
# * Beta (\beta)
# * Recto
# * Cateto Adyacente
# * Cateto Opuesto
# * Hipotenusa

# %%
x=np.array([0,4/5,4/5,0,])
y=np.array([0,0,3/5,0,])

#Figura
fig1=plt.figure(1)

# Grafica Triángulo 
color1 = [0/255,176/255,80/255]
plt.plot(x,y,color=color1,linewidth=2)

# Limites de ejes
plt.xlim([-1,7])
plt.ylim([-1,7])

# Cuadricula
color2 = [166/255,166/255,166/255]
plt.grid(axis='both',which='major',color=color2, linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=color2, linestyle=':', linewidth=1)

# Agrega texto
plt.text(-0.3,-0.1,'θ')
plt.text(0.5,0,'90°')
plt.text(1,1,'γ')
plt.text(0,-0.5,'Adyacente (A)')
plt.text(1.1,0.2,'Opuesto (O)')
plt.text(-1,0.7,'Hipotenusa (H)')
# Out:
# Text(-1, 0.7, 'Hipotenusa (H)')

# %% [markdown]
# **Ejercicio**
#
# Utiliza el anterior ejercicio con los siguientes puntos para construir un triángulo rectángulo azul:
#
# |Abcisa |Ordenada|
# | -| -|
# | 0 | 0 |
# |  $3^{1/2}$ | 0 |
# | $3^{1/2}$ | 1 |
# | 0 | 0 |

# %%
# Librerias
import numpy as np 
import scipy as sp
import pandas as pd

# Triángulo rectángulo
x=np.array([0,3**1/2,3**1/2,0])
y=np.array([0,0,1,0])

# Figura
fig1=plt.figure(1)

# Gráfica Triángulo 
color1 = [0/255,0/255,150/255]
plt.plot(x,y,color=color1,linewidth=2)

# Limites de ejes
plt.xlim([-1,7])
plt.ylim([-1,7])

# Cuadricula
color2 = [166/255,166/255,166/255]
plt.grid(axis='both',which='major',color=color2, linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=color2, linestyle=':', linewidth=1)

# %% [markdown]
# ##Conclusión
# Con esta tarea se aprendió una base importante tanto en clase como en casa, donde logramos experimentar diversas formas de dar estilo a los puntos y rectas de lo que grafiquemos en un plano cartesiano, además de delimitarlo, entre otros.
